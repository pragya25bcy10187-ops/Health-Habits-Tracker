# %%
import csv 
from datetime import date 





def check_water(water):
    if water >=6:
        return"6 cups ,Greater job on drinking enough water!"
    else:
        return"Try to drink more tomorrow."
        
def check_sleep(sleep):
    if 7<=sleep<=9:
        return "your sleep hours are perfect."
    else:
        return"try to get 7-9 hours of sleep."

def check_mood(mood):
    if mood>=7:
        return"you seem to be in a good mood today!"
    else:
        return"take some time for self-care to boost your mood."


def save_data(data):
    with open('data.csv','a',newline='')as file:
        writer= csv.writer(file)
        writer.writer(data)

def main():
    print("Welcome to Healthy Habits Tracker!")
    water=int(input("Enter glasses of water you drank today:"))
    sleep=float(input("Enter hours of sleep you got last night:"))
    mood=int(input("Rate your mood today (1-10):"))
